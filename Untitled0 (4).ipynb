# %% [markdown]
# # **Funciones: Utilidad, Tipos y Composición **
#
# espacio van ser pares ordenados de X y Y por qué tiene que ser pares ordenados Porque son dos bienes verdad y no es lo mismo consumir 2 l de agua y tres panes que 3 l de agua y dos panes el orden importa de acuerdo okay Cuál es el espacio correspondiente para trabajar con pares orden r por r excepto que acabamos de decir que estamos trabajando solamente con partes positivas de verdad entonces en la práctica el espacio en el que queremos trabajar es r má más arriba cre lo que suele ponerse r má Cruz r+ es decir el producto cartesiano
#
# ![image.png](data:image/png;base64,...)
#
#
# de los positivos con los positivos de acuerdo y así me garantizo que voy a tener cualquier par x y y va a ser una cantidad positiva del bien x y una cantidad positiva del bien y verdad y a Ese par ordenado le voy a asociar Exacto un nivel de bienestar un nivel de utilidad correspondiente al consumo de x y y de acuerdo Quiero saber si Clara la construcción de la función chere cierto porque a la finales con y llegas llegas número cosas y el caso particular en el que tienes dos bienes puedes generalizar la función el tema gráfico solamente para que le vean Entonces cuál es la intuición aquí si si yo consumo esta cantidad del bien x llamémosle x eh sub cero y esta cantidad del bien y llamémosle y sub c0 entonces voy a tener una combinación marchó voy a tener grabes el gráfico de la cabeza no voy a tener una combinación x sub y sub eh de los dos bienes eso es lo que se conoce como una cesta de bienes acuerdo una canasta de bienes y el consumo de esa canasta de bienes me representa un determinado nivel de utilidad que se va a medir dónde en el punto verdad de eh de coordenadas x y y altura u xy es decir va a ser un punto de la superficie
#
# ![image.png](data:image/png;base64,...)
#
# Entonces decíamos tenemos podemos tener una función de utilidad que va a tener una forma así relativamente arqueada y lo que dijimos es podemos pensar en una Concha Acústica de acuerdo listo y decíamos que si es que yo tengo aquí una cierta cantidad de x y de y tengo x0 aquí tengo y sub 0 entonces voy a tener en este punto Mi par de X sub cantidad de El bien x o digamos agua y y sub cantidad de pan ya y aquí arriba ejemplo voy a tener Qué cosa qu va estar ahí correcto la utilidad que me genera el consumo del bien X Y de acuerdo está claros los objetos que estamos manejando está claro por escogimos la superfici correcto punto necesariamente está sobre la superficie en el caso anterior estara sobre la curva en este caso no es curva superficie está sobre la superficie entonces noten que hay una correspondencia entre cada punto piso del plano que representa unaa distinta verdad es decir una combinación distinta de cantidad de x y cantidad de y y a cada uno de esos puntos a cada uno de esas pares de ordenados de cantidades le corresponde una un distinto nivel de utilidad recíprocamente a cada nivel eh o a cada punto en la superficie le corresponde verticalmente una canasta dada una combinación de x y y que representa esa utilidad dónde se pone esto interesante es que yo puedo tener dos puntos
#
# ![image.png](data:image/png;base64,...)
#
# distintos a la misma altura de acuerdo qué significa eso son dos canastas distintas que me representan la misma utilidad de acuerdo Entonces aquí es donde se puede empezar a plantear problemas de tipo económico responder preguntas como Okay Cuáles son eh todas las canastas que me dan una utilidad de 10 de acuerdo Entonces yo quiero que el individuo soy un dictador benevolente quiero que el individuo eh llegue a una a un nivel de utilidad mínimo de 10 de acuerdo Entonces lo que puedo hacer si conozco la función de utilidad del individuo Es okay Voy a establecer un un nivel de utilidad de 10 donde está el 10 digamos que está aquí okay Y voy a trazar voy voy a cortar la superficie de utilidad con un plano paralelo al piso de acuerdo Entonces así como aquí en el piso teníamos un ángulo recto Aquí también tenemos un ángulo recto sí ent estoy trazando un plano paralelo al piso que se va a cortar con mi función de eh de utilidad en diferentes puntos y yo lo que quiero preguntarme es Entonces los puntos en los que ese plano corte con mi superficie roja Qué representan representan todos los todos los puntos eh que me dan utilidad 10 Entonces supongamos es como un cuchillo no que le corta un pastel es un plano lea plan Exacto sí eh vamos si uso un rojo más profundo, entonces va a tener un corte en este lado y un corte en el otro lado entonces ahí estamos representando todos los puntos que tienen altura 10 y que están en la superficie ro está má menos Clara La idea Okay ahora representemos eso matemáticamente qué es lo que estamos pidiendo estamos pidiendo el conjunto de canastas verdad Esa era la pregunta cuál es el conjunto de canastas que dan
#
#
# ![image.png](data:image/png;base64,...)
#
# la misma utilidad está Clara la pregunta verdad cómo represento eso como un objeto matemático sería el conjunto de qué cómo representamos una canasta xy es el conjunto de pares x y pertenecientes a qué espacio r R r+ Cruz r+ o r + cuadrado como el espacio de partida De dónde sale la A dónde llega d porque Exacto preimagen es es algo que está en el espacio o sea es la preimagen de algo que está en el espacio de llegada y lo retrotrae al espacio de partida del mismo modo que la imagen es la imagen de algo que está en el espacio de partida y lo eh proyectas al espacio de llegada está claro ese concepto en este caso cuando escribimos esto aquí estamos pensando eh en algo que va a llegar a dónde al espacio de partida y es la imagen de un conjunto que está en
# dónde en el espacio de llegada estamos preguntándonos Cuáles son los elementos del espacio de partida sí tales que llegan Al conjunto 10 en mi espacio de llegada la representación esquemática de esto sería algo como esto yo tengo aquí r2 de hecho r + 2 verdad y aquí tengo r+ y tengo una función u que a cada punto de r + 2 le asocia un punto en r+ notan que aquí cambié la forma e implícitas o o eh los ejemplos de formas que representan espacio partida espacio
#
# Cómo Trabajamos para resolver un problema como este ya sabemos que esto aquí es F a la men1 de 10 sí F la -1 10 es este objeto acá Qué podemos hacer para resolver este problema ahora que tenemos la forma específica la función de utilidad vamos qué hacemos Ah tenemos este objeto qu cambió en relación a ayer ayer nuestros espacios eran a y b e y F etcétera ahora tenemos espacios numéricos bien definidos y Tenemos también una función de utilidad bien definida Qué información no hemos metido aquí ux es ra y correcto entonces
#
# Cuáles son las combinaciones de canastas que me dan un mismo nivel de utilidad y para los economistas esto Cómo se llama curvas de indiferencia de acuerdo las curvas de indiferencia son los las combinaciones de can de bienes que le garantizan al individuo el mismo nivel de utilidad de acuerdo Entonces las curvas de indiferencia no son otra cosa que el concepto de preimagen aplicado a la noción de una función de utilidad para describir el comportamiento de un individuo de acuerdo Entonces eso para que vean que los conceptos que estamos
#
#
# ![image.png](data:image/png;base64,...)
#
# manejando tienen un sentido económico una importancia práctica sí quiero saber si tienen alguna pregunta no está claro Okay noten ahora que la representación eh que estamos haciendo de las curvas de indiferencia es finalmente aquellos eh aquellos puntos del conjunto de puntos que en la función de utilidad me dan la misma altura verdad Entonces yo puedo también eh concebir gráficamente es más difícil de dibujar pero ver si intentemos un gráfico alternativo otra forma de dibujar eh objetos tridimensionales suele ser esta verdad
# una cosa es hablar de igualdad entre elementos de acuerdo decir igualdad entre elementos significa que mismo elemento que está a la izquierda está a la derecha del igual de acuerdo cuando hablo de igualdad de elementos es eso cuando hablo de igualdad de números es un tipo particular de igualdad de elementos sí lo que digo por ejemplo si es que x y y son números x = a y estoy diciendo que x y y son el mismo número o por ejemplo puedo decir que x es menor o igual que y y que x es mayor o igual que y una forma pomposa de decir es el mismo
#
# Omega esa es definición de una contención si es que si es que lo que tú quieres es una definición de una contención fuerte que sería sin eh sin la la la la linita debajo de la c de contención ya lo que podrías hacer es para todo x elemento de a eh x elemento de Omega y existe un elemento de Omega que no está en a ahí te garantizas que la contención es es fuerte pero eh la definición que está en eh escrita en en la clase uno la que estamos viendo en la pizarra es la correcta ya a contenido en Omega es cada elemento de X
