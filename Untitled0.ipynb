# %% [markdown]
# # ***Lógica Proposiciones y Conectores Lógicos***
#
# Proposición: Una proposición es una afirmación que puede ser verdadera (V) o falsa (F), pero no ambas.
#
# Ejemplos:
#
# p: "2 es un número par" (Verdadera)
#
# q: "3 es un número par" (Falsa)
#
# Conectores lógicos:
#
# Negación (¬): Invierte el valor de verdad de una proposición.
#
# Ejemplo:
# ¬p
#
# Conjunción (∧): Es verdadera si ambas proposiciones son verdaderas.
#
# Ejemplo:
# p∧q
#
# TABLAS DE VERDAD

# %% [markdown]
# ![Captura de pantalla 2024-06-29 232036.png](data:image/png;base64,...)

# %% [markdown]
# Disyunción (∨): Es verdadera si al menos una de las proposiciones es verdadera.
#
# Ejemplo:
# 𝑝∨𝑞
#
# Tabla de verdad:

# %% [markdown]
# ![Captura de pantalla 2024-06-29 234403.png](data:image/png;base64,...)

# %% [markdown]
# Implicación (→): Es falsa solo si la primera proposición es verdadera y la segunda es falsa.
#
# Ejemplo:
# p→q
#
# Tabla de verdad

# %% [markdown]
# ![Captura de pantalla 2024-06-29 234754.png](data:image/png;base64,...)

# %% [markdown]
# Doble implicación (↔): Es verdadera si ambas proposiciones tienen el mismo valor de verdad.
#
# Ejemplo:
# 𝑝↔𝑞
#
# Tabla de verdad

# %% [markdown]
# ![Captura de pantalla 2024-06-29 234917.png](data:image/png;base64,...)

# %% [markdown]
# La lógica y los conjuntos son fundamentos esenciales en matemáticas y programación. Aquí te proporcionaré información relevante sobre estos temas, incluyendo definiciones, conceptos clave, y ejemplos con diagramas y fórmulas.
#
# # **Fundamentos de Lógica:**
#
# La lógica es el estudio de los principios del razonamiento válido y la inferencia. Algunos conceptos importantes incluyen:
#
# 1. Proposiciones: Son declaraciones que pueden ser verdaderas o falsas.
# 2. Conectivos Lógicos: Son operadores que conectan proposiciones, como "y" (conjunción), "o" (disyunción), y "no" (negación).
# 3. Tablas de Verdad: Muestran todas las posibles combinaciones de verdad para un conjunto de proposiciones y sus conectivos lógicos.
#
#
# # **Teoría de Conjuntos**
# Definiciones Básicas
# Conjunto: Una colección de elementos distintos.
#
# Ejemplo:
# 𝐴={1,2,3}
#
# Un objeto que pertenece a un conjunto.
#
# Ejemplo:
# 1∈A
# Operaciones con Conjuntos Unión (∪): Conjunto de elementos que pertenecen a al menos uno de los conjuntos.
#
# Ejemplo:
# A∪B
#
# **Diagrama de Venn:**
# Intersección (∩): Conjunto de elementos que pertenecen a ambos conjuntos.
#
# Ejemplo:
# A∩B
#
# Diferencia (−): Conjunto de elementos que pertenecen a un conjunto pero no al otro.
#
# Ejemplo:
# A−B
#
# Complemento (𝐴𝑐): Conjunto de todos los elementos que no pertenecen al conjunto.
#
# Ejemplo:
# 𝐴𝑐
#
# # **Leyes de Conjuntos**
#
# Ley de Idempotencia:
# A∪A=A
# A∩A=A
#
# Ley de Conmutatividad:
# A∪B=B∪A
# A∩B=B∩A
#
# Ley de Asociatividad:
# (A∪B)∪C=A∪(B∪C)
# (A∩B)∩C=A∩(B∩C)
#
# Leyes de De Morgan:
# (A∪B=BU
# c
#  =A
# c
#  ∩B
# c
#
# (
# 𝐴
# ∩
# 𝐵
# )
# 𝑐
# =
# 𝐴
# 𝑐
# ∪
# 𝐵
# 𝑐
# (A∩B)
# c
#  =A
# c
#  ∪B
# c
#
#
# # **Diagrama de Venn:**
#
# Un diagrama de Venn es una representación visual de conjuntos y sus relaciones. Por ejemplo, en un diagrama de Venn con dos conjuntos A y B, la intersección representa los elementos que pertenecen a ambos conjuntos.
#
# Fundamentos de Conjuntos:
#
# Un conjunto es una colección de objetos distintos. Algunos conceptos clave en teoría de conjuntos son:
#
# 1. Elemento: Cada objeto individual en un conjunto.
# 2. Unión: El conjunto de todos los elementos que pertenecen a al menos uno de los conjuntos.
# 3. Intersección: El conjunto de elementos que pertenecen a ambos conjuntos.
# 4. Complemento: Los elementos que no pertenecen a un conjunto dado.
# 5. Diagrama de Conjuntos: Una representación visual de conjuntos y sus relaciones.
#
# # **Fórmulas Relevantes:**
#
# - Unión de conjuntos A y B: A \cup B
# - Intersección de conjuntos A y B: A \cap B
# - Complemento del conjunto A: A^c
#
# Estos conceptos son fundamentales en matemáticas y programación, ya que se utilizan en la resolución de problemas lógicos, algoritmos y estructuras de datos.

# %% [markdown]
# # **PROGRAMACION**

# %%
#CALCULANDO NUMEROS NATURALES#
def suma_naturales(n):
    suma = 0
    for i in range(1, n + 1):
        suma += i
    return suma
# Ejemplo de uso
n = 10
resultado = suma_naturales(n)
print(f"La suma de los primeros {n} números naturales es: {resultado}")
# Out:
# La suma de los primeros 10 números naturales es: 55
