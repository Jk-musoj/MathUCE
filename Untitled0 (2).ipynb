# %% [markdown]
# # ***Introducción a Python. ***
#
# Los computadores no solo realizan operaciones básicas, sino que necesitan programas para funcionar y los computadores cuánticos trabajan con qubits en lugar de ceros y unos.
#
# Los ordenadores necesitan programas para funcionar, incluso los cuánticos.
# Los computadores cuánticos utilizan qubits en lugar de ceros y unos.
# Los qubits permiten realizar procesamientos más rápidos al superponer unos y ceros.
#
# **# Una vez automatizado un proceso, el computador puede multiplicar más rápido que un humano.**
#
# # ✦Explicación sobre la diferencia entre lenguajes compilados e interpretados.
#
# Lenguaje compilado: traduce el código fuente una vez a lenguaje máquina.
#
# Lenguaje interpretado: traduce el código cada vez que se ejecuta el programa.
#
# Ejemplos de lenguajes compilados incluyen C y Java, mientras que Python es un lenguaje interpretado.
#
# # ✦Python es fácil de aprender y tiene una amplia gama de aplicaciones en desarrollo web, inteligencia artificial y aprendizaje automático, con una gran comunidad de desarrolladores y alta demanda en el mercado laboral.
#
# Python es ampliamente utilizado en el mercado laboral y las empresas que buscan programadores que separen Python.
#
# Se enfatiza que al programar, es mejor que el código sea simple y legible.
#
# Se menciona la importancia de utilizar los Jupyter Notebooks para combinar texto y código, permitiendo ejecutar programas con solo una conexión a Internet.
#
# # ✦Se explica cómo copiar y pegar celdas en un Jupiter Notebook y cómo reorganizarlas utilizando flechas.
#
# Se muestra cómo copiar una celda haciendo clic derecho y seleccionando "Copiar celda".
#
# Se explica que se puede pegar la celda en otra parte utilizando "Ctrl + B".
#
# También se menciona que las flechas en el Notebook son útiles para reorganizar las celdas, permitiendo moverlas hacia arriba o hacia abajo.
#
# # ✦Los números complejos pueden representarse como un par de coordenadas ayb, y cada número complejo tiene un conjugado simétrico en relación a la línea de los números reales.
#
# Cada complejo número se puede escribir como un par de coordenadas ay b.
#
# El conjugado de un número complejo tiene el mismo valor real pero con el signo opuesto en la coordinada imaginaria.
#
# Los números complejos se pueden representar en el plano complejo como pares ordenados, análogos a trabajar en R2.
#
# # ✦Se explica la construcción de productos cartesianos con ejemplos de conjuntos interesantes como N y R^n.
#
# Se menciona que un producto cartesiano puede extenderse a más de dos conjuntos.
#
# Se ejemplifica la construcción de productos cartesianos con más elementos como R^3.
#
# Se discute la extensión de la definición a espacios como R^n.
#
# # ✦Se discute la diferencia entre secuencias finitas e infinitas, y la noción de infinito en conjuntos infinitos.
#
# Se menciona la diferencia estructural entre secuencias finitas e infinitas.
#
# Se destaca que no todas las infinitudes tienen el mismo tamaño.
#
# Se plantea la necesidad de refinar la idea de cardinalidad al tratar con conjuntos infinitos.
#
#
# Ejecución de Código:
#
# Python es un lenguaje interpretado, lo que significa que puedes ejecutar instrucciones línea por línea o ejecutar archivos completos de código.
#
# Variables en Python:
#
# Declaración y Asignación:

# %%
# Declaración y asignación de variables
edad = 25
nombre = "Juan"

# %% [markdown]
# Operadores en Python:
#
# Operadores Aritméticos:

# %%
# Ejemplos de operadores aritméticos
suma = 5 + 3
resta = 7 - 2
multiplicacion = 4 * 6
division = 10 / 2

# %% [markdown]
# Operadores Lógicos:

# %%
# Ejemplos de operadores lógicos
and_logico = (True and False)  # False
or_logico = (True or False)  # True
not_logico = not True  # False

# %% [markdown]
# # Principios de Demostración Matemática:
#
# **Demostración Directa:**
#
# Se parte de supuestos y se siguen pasos lógicos para llegar a una conclusión.
#
# Ejemplo: Demostrar que la suma de dos números pares es siempre par.
#
# **Demostración por Contrapositiva:**
#
# Se demuestra la afirmación negando la conclusión y mostrando que esto implica la negación de la premisa.
#
# Ejemplo: Demostrar que si
#
# 𝑛^2 es par, entonces n es par.
#
# **Demostración por Contradicción:**
#
# Se asume que la afirmación es falsa y se demuestra que esto lleva a una contradicción.
#
# Ejemplo: Demostrar que
#
# √2 es irracional.
#
# Estos principios son fundamentales en la lógica matemática para construir argumentos válidos y llegar a conclusiones demostrables.
