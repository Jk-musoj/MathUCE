# %% [markdown]
# # **Funciones Matemáticas**
#
# **Imagen y Preimagen**
#
# **Funciones:**
#
# Una función
# f:A→B asigna cada elemento de un conjunto
# 𝐴 (dominio) a un elemento en un conjunto 𝐵 (codominio).
#
# **Imagen:**
#
# La imagen de un elemento
#
# 𝑎 bajo la función 𝑓 es(𝑎)
#
#
# **La imagen de un subconjunto **
#
# S⊆A es el conjunto de todas las imágenes de los elementos de S, es decir, f(S)={f(s)∣s∈S}.
#
# Ejemplo: Si
#
# f(x)=x2 y A={1,2,3}, entonces la imagen de 2 es f(2)=4.
#
# **Preimagen:**
#
# La preimagen de un elemento b en 𝐵 es el conjunto de todos los elementos a en A tales que f(a)=b.
#
# **La preimagen de un subconjunto **
#
# T⊆B es el conjunto de todos los elementos de A que se mapean a T bajo f, es decir, 𝑓−1(𝑇)={𝑎∈𝐴∣𝑓(𝑎)∈𝑇}
#
# Ejemplo: Si 𝑓(𝑥)=𝑥2f(x)=x 2 y 𝐵={1,4,9} la preimagen de 4 es {2,−2}.
#
# cuando tenemos conjuntos que pertenecen que son están contenidos en un conjunto general Omega si tenemos dos conjuntos (a y b) podemos interceptarlos podemos hacer la la unión entre ellos podemos sacar complementos diferencias etcétera eh lo mismo si tenemos más conjuntos Pero qué pasa si en lugar de tener (a y b )que son subconjuntos de de un mismo conjunto Omega tenemos dos conjuntos distintos Entonces ahora no va a decir ah Están contenidos en Omega sino sol va a decir sean (a y b) dos conjuntos entonces una función la vamos a tener como (a)
#
# entender como una regla de asociación una función de a es una regla de asociación que a cada elemento x perteneciente a (a) le le asigna le asocia un único elemento y perteneciente (a)
#
#
# ![image.png](data:image/png;base64,...)
#
# f(dx) Entonces si nosotros descomponemos está Clara función descomponemos  o identificamos los elementos de la definición resulta entonces que una función tiene un nombre de acuerdo a una regla de asociación, esta regla de asociación expresa una relación entre el elemento el espacio de partida y  el elemento el espacio de llegada que le escribimos como y f(g).
#
# cuando tenemos toda esa definición Clara bien internalizada todo lo podemos resumir de la siguiente manera F es el nombre de la función es una función que parte de a es el espacio de partida El dominio y llega a b que sería el espacio de llegada y a cada x elemento de a le asocia un y elemento de B que va a ser la imagen de X de acuerdo Entonces ahí tenemos toda la definición de la de la
# función de la forma más compacta y matematizar de asociación que parte de un espacio a a un espacio b y a cada elemento x de a le asocia un único elemento y que es la imagen de X de acuerdo aquí hay alguna pregunta estados listo entonces volviendo al ejemplo inicial y les decía La idea es completarlo completar la noción de función cuando nosotros planteamos algo como esto fdx = 3x cu no tenemos realmente una función tenemos solamente la regla de sucesión pero no sabemos por ejemplo Qué son los X los X pueden ser números enteros pueden ser números reales o incluso pueden ser matrices de acuerdo o pueden llegar a ser funciones también entonces para completar la noción de función necesitamos definir el resto de elementos para esta regla de asociación en este caso sería Eh inferir entonces eh si por ejemplo estamos trabajando sobre el conjunto de los números reales voy ar esta esta función expresión no hay có cortar porque no ya se puede
# ![image.png](data:image/png;base64,...)
#
# para completar esto y convertirlo en una función vemos todo caso ya tenemos algunos de los elementos tenemos la regla de asociación y el nombre de la función verdad Entonces podríamos decir que en este caso F es una función que va por ejemplo del espacio de los números reales
#
# es si consideramos el conjunto si consideramos el conjunto a como el conjunto de palabras en idioma Castellano y el conjunto B como el conjunto de las letras del alfabeto que van desde la a hasta la z Entonces nosotros podemos pensar en una función eh voy a llamar esta vez I que vaya del conjunto a de palabras en idioma Castellano Al conjunto B
#
# Entonces estamos diciendo tenemos dos conjuntos a y b una función F de a es una regla de asociación que a cada elemento x de a le asigna un único elemento y en B al que se lo denomina la imagen a través de F entonces podemos expresar parte de toda esta definición numéricamente y podemos decir que entonces en una función F que va de AB es una regla de asociación tal que para todo x o para cada elemento x de a para todo x elemento de a existe un único elemento y en B si yo
# pongo así existe un y elemento de B eh Me falta un detalle y es que no estoy diciendo que es único para explicitar que es único solemos poner aquí un signo de exclamación esto se le como existe un único de acuerdo sí Entonces para todo x elemento de a existe un único y elemento de B tal que y es igual a f (dx)
#
#
# ![image.png](data:image/png;base64,...)
#
#
# ![image.png](data:image/png;base64,...)
#
# relación de menor O igual ya la relación de menor o igual es una función que va en este caso de r CR r parce Enton mi d el problem t pantall quieres completar aquí abajo aquí abajo de r cu = x y no es tan fácil cierto y esa es la gran pregunta Cuando manejamos una relación binaria queremos relacionar los elementos entre sí y ver si cumple o no una determinada relación de acuerdo el espacio de llegada es el conjunto binario que puede ser 0 un sí o no cumple o no cumple Cuál es el conjunto de salida  podemos establecer que la relación es menor o igual tomando un par de números X y Y nuevamente del espacio r2 nuestro espacio de llegada en este caso sería solamente el conjunto 01 y a cada xy podemos asociarle r de x y es igual a 1 si x es menor o igual que y o rxy = 0 si no ahí está nuestra regla de asociación verdad y a cada par de elementos de los números reales yo puedo decir si la relación de menor o igual que me relaciona al primer elemento del par con el segundo elemento del par se cumple o no se cumple de acuerdo Entonces ahí tenemos otro ejemplo de una función por último eh el último de los ejemplos que vimos en clases pasadas Recuerden que cuando creá el espacio r eh a la n que era el producto que era un vector eh de n coordenadas un nupla donde cada coordenada era Era un un real eh Era uno de los ejemplos y el otro era r a la n que dijimos era el conjunto qu
# era r a la n natural era eso recuerdan si r a un número natural específico eran vectores de n coordenadas qué será r a la n natural Necesito que revisen los materiales que que vamos viendo si no van a estar absolutamente perdidos porque los exámenes construyen sobre los conceptos que hemos visto y va a haber un solo examen recuerden haa tres semanas Entonces si les parece que hemos revisado bastantes conceptos en la primera semana imaginen segunda y tercera semana de acuerdo Entonces lo que decíamos es que r a la n es el
# conjunto compuesto por vectores de Dimensión infinita es decir secuencias infinitas donde para todo y perteneciente los naturales x es Los Reales eso es lo que habíamos dicho de r Entonces qué es este objeto de acá Este objeto acá No es otra cosa que una secuencia de números una secuencia ordenada que empieza por x1 luego x2 X3 etcétera Solo que esta era la forma más elegante más precisa de expresar de acuerdo.
#
# ![image.png](data:image/png;base64,...)
#
# puedo definir F de r es decir la imagen de el conjunto de Los Reales como el conjunto de los X cu + 1 tales que x pertenece a Los Reales ahora tengo algo un poco más desarrollado Entonces si si x puede tomar cualquier valor real Qué valor Eh me espera en x cu un real puede ser positivo o negativo Pero si le elevo al cuadrado No necesariamente es un natural si es que tomo cualquier real el el resultado mi imagen va a ser un real positivo ya y cuál es el más pequeño real positivo que puede haber el cer verdad Pero no solo que eh Le estoy
# elevando al cuadrado para hacerle positivo a x sino que además le estoy sumando uno entonces el más pequeño número que puedo obtener es el 1o eso significa que esto de aquí el conjunto de los X cu + 1 tal que x pertenece a r No es otra cosa que el conjunto de eh eh de los X pertenecientes a Los Reales tal que x es mayor o igual que 1 entonces lo que estoy diciendo es que para esta función F definida como FX = x cu + 1 la imagen de Los Reales No es otra cosa que el intervalo que va de cer al infinito.
#
# ![image.png](data:image/png;base64,...)
#
#
# Entonces le pongo n pertenece a los naturales y le uno a la unión negativa pongo n perteneciente a los enteros relativos no me gusta pero bueno Entonces esta Unión de aquí corresponde justamente a todos los intervalos que me cumplen con que son preimagen de de senos positivos está claro Entonces como pueden ver los objetos siguen siendo los mismos la definición de imagen y preimagen sigue siendo la misma pero la respuesta siempre requiere un problema
